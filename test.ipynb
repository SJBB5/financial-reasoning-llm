# %%
# %run run_demo.py
# Out:
# ticker: AAPL
# [*********************100%***********************]  1 of 1 completed
# /Users/sambrown04/Documents/570/financial-reasoning-llm/src/anomaly_detection.py:11: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "move": float(row["return_pct"]),
# finding big moves...
# found 37 big moves
#
# getting news from finviz...
# recent headlines:
# - Stock market today: Dow, S&P 500, Nasdaq slide as bitcoin tumbles to kick off December
# - Wall Street Continues to Underestimate the Growth of Magnificent Seven Companies. Here's Why.
# - Intel Could Break Through Apple Barrier -- Analysts Say This Could Redefine Foundry Competition
# - Stock market today: Dow, S&P 500, Nasdaq slip, bitcoin plummets in rocky start to December
# - Stock market today: Dow, S&P 500, Nasdaq slide, bitcoin plummets in rocky start to December
# - Final Trades: Nike, Amazon, Delta Air Lines and Apple
# ...
